# %% [markdown]
# # CSCI 1360 - Assignment 6
# ## Question 1
#
# - Total points 50

# %% [markdown]
# ### Part A (Linear Regression), 50 points
#
# ![image.png](attachment:image.png)
#
# The RMS Titanic met its tragic end during the early morning hours of April 15, 1912, in the North Atlantic Ocean. This occurred just four days into its inaugural journey from Southampton to New York City. As the largest ocean liner in operation at the time, the Titanic carried approximately 2,224 passengers. The ship struck an iceberg at approximately 23:40 on Sunday, April 14, 1912, according to the ship's time. Subsequently, it sank two hours and forty minutes later at 02:20 on Monday, April 15 (05:18 GMT), leading to the loss of more than 1,500 lives. This event stands as one of the deadliest peacetime maritime disasters in history.
#
# We will try, through data science, to analyze what sorts of people were more likely to survive the disaster? using passenger data (i.e., age, gender, socio-economic class, etc) retrieved from [Kaggle](https://www.kaggle.com/competitions/titanic/overview). [train.csv](train.csv) is the training data you can use. Survival predictions will be performed on [test.csv](test.csv). The dataset contains the following features:
#
# - PassengerId
# - Survived (Binary label)
# - Pclass (Ticket class)
# - Sex
# - Age
# - SibSp (No. of siblings / spouses aboard the Titanic)
# - Parch (No. of parents / children aboard the Titanic)
# - Fare (Passenger fare)
# - Embarked (Port of Embarkation. C = Cherbourg, Q = Queenstown, S = Southampton)
#
# Use machine learning to create a linear regression model that predicts which passengers survived the Titanic shipwreck. Submit your predictions in a csv file that contains two features, `PassengerId` and `Survived`. The later will be the prediction column filled with binary labels. Along with the csv file, you will need to submit this notebook, which is supposed to include your solution.  Initially you would need to examine the dataset and determine what preprocessing steps are needed. Following that, training and testing steps can be performed.
#
# - You are encouraged to create multiple cells in your notebook.
# - The only packages that are allowed in your solution are: `sklearn`, `pandas` and `numpy`.
# - Only categorical features need to be encoded.
# - An ideal solution would utilize your vectorized programming skills, such as slicing and fancy indexing.
#
# #### Grading Rubric
# - Correct file loading
# - Extract the labels column
# - Model training
# - Correct predictions
# - Correct file format

# %%
# You solution goes here
# you are encouraged to use multiple cells in the notebook
